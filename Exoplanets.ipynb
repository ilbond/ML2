# %% [markdown]
# # Классификация экзопланет

# %% [markdown]
# *Экзопланета* (внесолнечная планета) — планета, находящаяся вне Солнечной системы.

# %% [markdown]
# ## Постановка задачи
# Внесолнечные планеты (extrasolar planets) можно разделить по классам:
#
# 1. Планета, вращающаяся по орбите вокруг одиночной звезды
# 2. Планета, вращающаяся по орбите S-типа вокруг двойной звезды
# 3. Планета, вращающаяся по орбите P-типа вокруг двойной звезды
# 4. Планета-сирота (межзвездная планета) - объект, являющийся по сути планетой, но не привязанный гравитационно ни к какой звезде.

# %% [markdown]
# Будем решать задачу в рамках данной выше классификации (по характеристикам небесного тела отнесем его к одному из четырех классов)

# %% [markdown]
# ## Работа с данными

# %% [markdown]
# Возьмем открытый датасет с характеристиками экзопланет. Ссылка на датасет: https://www.kaggle.com/mrisdal/open-exoplanet-catalogue

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.utils import resample, shuffle
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Прочитаем данные.

# %%
data = pd.read_csv("oec.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3584 entries, 0 to 3583
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PlanetIdentifier      3584 non-null   object
#  1   TypeFlag              3584 non-null   int64
#  2   PlanetaryMassJpt      1313 non-null   float64
#  3   RadiusJpt             2774 non-null   float64
#  4   PeriodDays            3485 non-null   float64
#  5   SemiMajorAxisAU       1406 non-null   float64
#  6   Eccentricity          1108 non-null   float64
#  7   PeriastronDeg         328 non-null    float64
#  8   LongitudeDeg          43 non-null     float64
#  9   AscendingNodeDeg      46 non-null     float64
#  10  InclinationDeg        665 non-null    float64
#  11  SurfaceTempK          741 non-null    float64
#  12  AgeGyr                2 non-null      float64
#  13  DiscoveryMethod       3521 non-null   object
#  14  DiscoveryYear         3574 non-null   float64
#  15  LastUpdated           3576 non-null   object
#  16  RightAscension        3574 non-null   object
#  17  Declination           3574 non-null   object
#  18  DistFromSunParsec     2133 non-null   float64
#  19  HostStarMassSlrMass   3416 non-null   float64
#  20  HostStarRadiusSlrRad  3263 non-null   float64
#  21  HostStarMetallicity   2509 non-null   float64
#  22  HostStarTempK         3455 non-null   float64
#  23  HostStarAgeGyr        517 non-null    float64
#  24  ListsPlanetIsOn       3584 non-null   object
# dtypes: float64(18), int64(1), object(6)
# memory usage: 700.1+ KB

# %% [markdown]
# Разберемся с признаками.
# 1. PlanetIdentifier - название небесного тела.
# 2. TypeFlag - тип планеты (0=планета, вращающаяся вокруг одной звезды; 1=планета с орбитой P-типа; 2=планета с орбитой S-типа; 3=планета-сирота).
# 3. PlanetaryMassJpt - масса планеты (в массах Юпитера).
# 4. RadiusJpt - радиус планеты (в радиусах Юпитера).
# 5. PeriodDays - период обращения (в днях).
# Кеплеровы элементы орбиты (6 элементов):
#
# 1. SemiMajorAxisAU - большая полуось (в астрономических единицах).
# 2. Eccentricity - эксцентриситет орбиты.
# 3. PeriastronDeg - аргумент перицентра (в градусах).
# 4. LongitudeDeg - долгота (в градусах).
# 5. AscendingNodeDeg - узел орбиты (в градусах).
# 6. InclinationDeg - наклонение (в градусах).
#
# 1. SurfaceTempK - температура поверхности планеты (в кельвинах).
# 2. AgeGyr - возраст планеты (млрд. лет).
# 3. DiscoveryMethod - метод обнаружения.
# 4. DiscoveryYear - год обнаружения.
# 5. LastUpdated - дата последнего обновления.
# 6. RightAscension - прямое восхождение (в часовой мере) +/-hh mm ss.
# 7. Declination - склонение (в часовой мере) hh mm ss.
# 8. DistFromSunParsec - расстояние от Солнца (в парсеках).
# 9. HostStarMassSlrMass - масса "хозяйской" звезды (в массах Солнца).
# 10. HostStarRadiusSlrRad - радиус "хозяйской" звезды (в радиусах Солнца).
# 11. HostStarMetallicity - металличность "хозяйской" звезды.
# 12. HostStarTempK - температура "хозяйской" звезды (в кельвинах).
# 13. HostStarAgeGyr - возраст "хозяйской" звезды (млрд. лет).
# 14. ListsPlanetIsOn - список, в который включена планета

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Удалим столбцы, в которых более половины значений пропущено. Также удалим столбцы LastUpdatedи PlanetIdentifier, т.к. они не несут никакой полезной информации.

# %%
data = data.drop(['PlanetaryMassJpt','SemiMajorAxisAU', 'Eccentricity', 'PeriastronDeg', 'LongitudeDeg', 'AscendingNodeDeg', 'InclinationDeg', 'SurfaceTempK', 
                 'AgeGyr', 'HostStarAgeGyr', 'LastUpdated', 'PlanetIdentifier'], axis=1)

# %% [markdown]
# Заполним столбцы RadiusJpt,PeriodDays, DistFromSunParsec, HostStarMetallicity, HostStarMassSlrMass, HostStarRadiusSlrRad и HostStarTempK медианой.

# %%
def fillmedian(names_cols: list):
    for name in names_cols:
        data[name] = data[name].fillna(data[name].median())
fillmedian(['RadiusJpt', 'PeriodDays', 'DistFromSunParsec', 'HostStarMetallicity', 'HostStarMassSlrMass', 'HostStarRadiusSlrRad', 'HostStarTempK'])

# %%
data['DiscoveryMethod'].value_counts()
# Out:
# transit         2712
# RV               692
# imaging           52
# microlensing      40
# timing            25
# Name: DiscoveryMethod, dtype: int64

# %% [markdown]
# Чаще всего используется транзитный метод обнаружения. Заполним им пропуски в столбце DiscoveryMethod

# %%
data['DiscoveryMethod'] = data['DiscoveryMethod'].fillna('transit')

# %% [markdown]
# Аналогично поступим с DiscoveryYear

# %%
data['DiscoveryYear'].value_counts()
# Out:
# 2016.0    1415
# 2014.0     928
# 2015.0     199
# 2011.0     189
# 2013.0     140
# 2012.0     131
# 2010.0     120
# 2009.0      81
# 2008.0      66
# 2007.0      64
# 2005.0      34
# 2002.0      30
# 2004.0      30
# 2006.0      30
# 2017.0      27
# 2003.0      25
# 2000.0      20
# 2001.0      13
# 1999.0      11
# 1996.0       6
# 1998.0       5
# 1992.0       4
# 1930.0       1
# 1995.0       1
# 1994.0       1
# 1846.0       1
# 1997.0       1
# 1781.0       1
# Name: DiscoveryYear, dtype: int64

# %%
data['DiscoveryYear'] = data['DiscoveryYear'].fillna(2016.0)

# %%
data['RightAscension']
# Out:
# 0             16 01 03
# 1             16 01 03
# 2          19 00 03.14
# 3          19 00 03.14
# 4          19 00 03.14
#              ...
# 3579    01 08 35.39148
# 3580    01 08 35.39148
# 3581          12 30 26
# 3582          12 30 26
# 3583          19 22 33
# Name: RightAscension, Length: 3584, dtype: object

# %%
data['Declination']
# Out:
# 0            +33 18 13
# 1            +33 18 13
# 2          +40 13 14.7
# 3          +40 13 14.7
# 4          +40 13 14.7
#              ...
# 3579    -10 10 56.1570
# 3580    -10 10 56.1570
# 3581         +22 52 47
# 3582         +22 52 47
# 3583         +48 59 46
# Name: Declination, Length: 3584, dtype: object

# %% [markdown]
# Есть два столбца RightAscension и Declination типа object (строка). Они содержат данные, заданные в часовой мере. Переведем их в радианы.

# %%
def todegree(s: str):
    if pd.notna(s):
        ans = 0
        k = 1
        l = 3600
        if s[0] == '-':
            k = -1
        for elem in list(map(float, s.split())):
            ans += elem * l
            l //= 60
        return k * math.pi / 43200 * ans
    
    return s

data['RightAscension'] = data['RightAscension'].apply(todegree)
data['Declination'] = data['Declination'].apply(todegree)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3584 entries, 0 to 3583
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TypeFlag              3584 non-null   int64
#  1   RadiusJpt             3584 non-null   float64
#  2   PeriodDays            3584 non-null   float64
#  3   DiscoveryMethod       3584 non-null   object
#  4   DiscoveryYear         3584 non-null   float64
#  5   RightAscension        3574 non-null   float64
#  6   Declination           3574 non-null   float64
#  7   DistFromSunParsec     3584 non-null   float64
#  8   HostStarMassSlrMass   3584 non-null   float64
#  9   HostStarRadiusSlrRad  3584 non-null   float64
#  10  HostStarMetallicity   3584 non-null   float64
#  11  HostStarTempK         3584 non-null   float64
#  12  ListsPlanetIsOn       3584 non-null   object
# dtypes: float64(10), int64(1), object(2)
# memory usage: 364.1+ KB

# %% [markdown]
# Посмотрим в каких строках остались пропуски.

# %%
data[data['RightAscension'].isna()]
# Out:
#      TypeFlag  RadiusJpt  PeriodDays DiscoveryMethod  DiscoveryYear  \
# 408         0   0.034902     87.9700         transit         2016.0
# 409         0   0.086565    224.7000         transit         2016.0
# 410         0   0.091130    365.2422         transit         2016.0
# 411         0   0.048489    686.9800         transit         2016.0
# 412         0   1.000000   4332.8200         transit         2016.0
# 413         0   0.832944  10755.6700         transit         2016.0
# 414         0   0.362775  30687.1530         transit         1781.0
# 415         0   0.352219  60190.0300         transit         1846.0
# 416         0   0.016438  90553.0200         transit         1930.0
# 995         0   1.200000      3.3000         transit         2011.0
#
#      RightAscension  Declination  DistFromSunParsec  HostStarMassSlrMass  \
# 408             NaN          NaN              333.0                1.000
# 409             NaN          NaN              333.0                1.000
# 410             NaN          NaN              333.0                1.000
# 411             NaN          NaN              333.0                1.000
# 412             NaN          NaN              333.0                1.000
# 413             NaN          NaN              333.0                1.000
# 414             NaN          NaN              333.0                1.000
# 415             NaN          NaN              333.0                1.000
# 416             NaN          NaN              333.0                1.000
# 995             NaN          NaN              333.0                0.977
#
#      HostStarRadiusSlrRad  HostStarMetallicity  HostStarTempK  \
# 408                   1.0         1.000000e-08         5778.0
# 409                   1.0         1.000000e-08         5778.0
# 410                   1.0         1.000000e-08         5778.0
# 411                   1.0         1.000000e-08         5778.0
# 412                   1.0         1.000000e-08         5778.0
# 413                   1.0         1.000000e-08         5778.0
# 414                   1.0         1.000000e-08         5778.0
# 415                   1.0         1.000000e-08         5778.0
# 416                   1.0         1.000000e-08         5778.0
# 995                   1.0         2.000000e-02         5700.0
#
#        ListsPlanetIsOn
# 408       Solar System
# 409       Solar System
# 410       Solar System
# 411       Solar System
# 412       Solar System
# 413       Solar System
# 414       Solar System
# 415       Solar System
# 416       Solar System
# 995  Confirmed planets

# %%
data[data['Declination'].isna()]
# Out:
#      TypeFlag  RadiusJpt  PeriodDays DiscoveryMethod  DiscoveryYear  \
# 408         0   0.034902     87.9700         transit         2016.0
# 409         0   0.086565    224.7000         transit         2016.0
# 410         0   0.091130    365.2422         transit         2016.0
# 411         0   0.048489    686.9800         transit         2016.0
# 412         0   1.000000   4332.8200         transit         2016.0
# 413         0   0.832944  10755.6700         transit         2016.0
# 414         0   0.362775  30687.1530         transit         1781.0
# 415         0   0.352219  60190.0300         transit         1846.0
# 416         0   0.016438  90553.0200         transit         1930.0
# 995         0   1.200000      3.3000         transit         2011.0
#
#      RightAscension  Declination  DistFromSunParsec  HostStarMassSlrMass  \
# 408             NaN          NaN              333.0                1.000
# 409             NaN          NaN              333.0                1.000
# 410             NaN          NaN              333.0                1.000
# 411             NaN          NaN              333.0                1.000
# 412             NaN          NaN              333.0                1.000
# 413             NaN          NaN              333.0                1.000
# 414             NaN          NaN              333.0                1.000
# 415             NaN          NaN              333.0                1.000
# 416             NaN          NaN              333.0                1.000
# 995             NaN          NaN              333.0                0.977
#
#      HostStarRadiusSlrRad  HostStarMetallicity  HostStarTempK  \
# 408                   1.0         1.000000e-08         5778.0
# 409                   1.0         1.000000e-08         5778.0
# 410                   1.0         1.000000e-08         5778.0
# 411                   1.0         1.000000e-08         5778.0
# 412                   1.0         1.000000e-08         5778.0
# 413                   1.0         1.000000e-08         5778.0
# 414                   1.0         1.000000e-08         5778.0
# 415                   1.0         1.000000e-08         5778.0
# 416                   1.0         1.000000e-08         5778.0
# 995                   1.0         2.000000e-02         5700.0
#
#        ListsPlanetIsOn
# 408       Solar System
# 409       Solar System
# 410       Solar System
# 411       Solar System
# 412       Solar System
# 413       Solar System
# 414       Solar System
# 415       Solar System
# 416       Solar System
# 995  Confirmed planets

# %% [markdown]
# Интересно то, что пропуски оказались в строках с планетами Солнечной системы и одной из планет WASP-53. Пока оставим этот вопрос и заполним пропуски нулями.

# %%
data['Declination'] = data['Declination'].fillna(0)
data['RightAscension'] = data['RightAscension'].fillna(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3584 entries, 0 to 3583
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TypeFlag              3584 non-null   int64
#  1   RadiusJpt             3584 non-null   float64
#  2   PeriodDays            3584 non-null   float64
#  3   DiscoveryMethod       3584 non-null   object
#  4   DiscoveryYear         3584 non-null   float64
#  5   RightAscension        3584 non-null   float64
#  6   Declination           3584 non-null   float64
#  7   DistFromSunParsec     3584 non-null   float64
#  8   HostStarMassSlrMass   3584 non-null   float64
#  9   HostStarRadiusSlrRad  3584 non-null   float64
#  10  HostStarMetallicity   3584 non-null   float64
#  11  HostStarTempK         3584 non-null   float64
#  12  ListsPlanetIsOn       3584 non-null   object
# dtypes: float64(10), int64(1), object(2)
# memory usage: 364.1+ KB

# %% [markdown]
# ## Категориальные признаки

# %% [markdown]
# Имеется два категориальных признака - DiscoveryMethod и ListsPlanetIsOn. Посмотрим на их структуру.

# %%
data['ListsPlanetIsOn'].unique()
# Out:
# array(['Confirmed planets', 'Controversial',
#        'Confirmed planets, Planets in binary systems, S-type',
#        'Controversial, Planets in binary systems, S-type',
#        'Confirmed planets, Planets in binary systems, P-type',
#        'Controversial, Planets in binary systems, P-type', 'Solar System',
#        'Confirmed planets, Planets in open clusters',
#        'Confirmed planets, Orphan planets', 'Retracted planet candidate',
#        'Confirmed planets, Planets in binary systems, P-type, Planets in globular clusters',
#        'Planets in binary systems, S-type, Confirmed planets',
#        'Kepler Objects of Interest'], dtype=object)

# %% [markdown]
# Столбец ListsPlanetIsOn непостредственно содержит признак, который мы собираемся предсказывать (словесная форма с некоторыми дополнениями столбца TypeFlag. Поэтому удалим его.

# %%
data = data.drop('ListsPlanetIsOn', axis=1)

# %% [markdown]
# Теперь посмотрим на столбец DiscoveryMethod

# %%
data['DiscoveryMethod'].unique()
# Out:
# array(['RV', 'transit', 'microlensing', 'imaging', 'timing'], dtype=object)

# %% [markdown]
# Используем One-Hot Encoding, чтобы обработать этот столбец.

# %%
data = pd.get_dummies(data)

# %% [markdown]
# ## Визуализация данных и вычисление характеристик

# %% [markdown]
# Проверим корреляцию столбцов

# %%
data.corr()
# Out:
#                               TypeFlag  RadiusJpt  PeriodDays  DiscoveryYear  \
# TypeFlag                      1.000000   0.059762    0.100420      -0.152768
# RadiusJpt                     0.059762   1.000000    0.002780      -0.058108
# PeriodDays                    0.100420   0.002780    1.000000      -0.187536
# DiscoveryYear                -0.152768  -0.058108   -0.187536       1.000000
# RightAscension               -0.145948  -0.184083   -0.024034       0.289601
# Declination                  -0.122727  -0.170921   -0.063685       0.210635
# DistFromSunParsec            -0.084542   0.020433   -0.028929       0.041826
# HostStarMassSlrMass           0.020262   0.199792    0.082905      -0.077677
# HostStarRadiusSlrRad          0.041417  -0.008747    0.006878      -0.066379
# HostStarMetallicity           0.030627   0.081811   -0.029667      -0.064103
# HostStarTempK                -0.007808   0.121828    0.069858      -0.009869
# DiscoveryMethod_RV            0.190539  -0.157514    0.019986      -0.338186
# DiscoveryMethod_imaging       0.087521   0.119409    0.283626      -0.048936
# DiscoveryMethod_microlensing  0.013100  -0.035636   -0.000679      -0.032519
# DiscoveryMethod_timing        0.091285  -0.028113    0.023123      -0.065231
# DiscoveryMethod_transit      -0.226398   0.129116   -0.104427       0.354457
#
#                               RightAscension  Declination  DistFromSunParsec  \
# TypeFlag                           -0.145948    -0.122727          -0.084542
# RadiusJpt                          -0.184083    -0.170921           0.020433
# PeriodDays                         -0.024034    -0.063685          -0.028929
# DiscoveryYear                       0.289601     0.210635           0.041826
# RightAscension                      1.000000     0.337498           0.183662
# Declination                         0.337498     1.000000           0.036620
# DistFromSunParsec                   0.183662     0.036620           1.000000
# HostStarMassSlrMass                -0.114411    -0.019489          -0.107637
# HostStarRadiusSlrRad               -0.158029    -0.051984          -0.054388
# HostStarMetallicity                 0.018024    -0.024238           0.012156
# HostStarTempK                       0.054232     0.080142           0.089772
# DiscoveryMethod_RV                 -0.501126    -0.220903          -0.281983
# DiscoveryMethod_imaging            -0.076856    -0.079912          -0.058276
# DiscoveryMethod_microlensing        0.020514    -0.076341           0.608630
# DiscoveryMethod_timing             -0.006505    -0.097080           0.009184
# DiscoveryMethod_transit             0.491267     0.269936           0.128136
#
#                               HostStarMassSlrMass  HostStarRadiusSlrRad  \
# TypeFlag                                 0.020262              0.041417
# RadiusJpt                                0.199792             -0.008747
# PeriodDays                               0.082905              0.006878
# DiscoveryYear                           -0.077677             -0.066379
# RightAscension                          -0.114411             -0.158029
# Declination                             -0.019489             -0.051984
# DistFromSunParsec                       -0.107637             -0.054388
# HostStarMassSlrMass                      1.000000              0.392496
# HostStarRadiusSlrRad                     0.392496              1.000000
# HostStarMetallicity                      0.147669             -0.116323
# HostStarTempK                            0.317047             -0.070830
# DiscoveryMethod_RV                       0.165330              0.287663
# DiscoveryMethod_imaging                 -0.037756             -0.020783
# DiscoveryMethod_microlensing            -0.192322             -0.016505
# DiscoveryMethod_timing                   0.013021             -0.017826
# DiscoveryMethod_transit                 -0.099564             -0.257959
#
#                               HostStarMetallicity  HostStarTempK  \
# TypeFlag                                 0.030627      -0.007808
# RadiusJpt                                0.081811       0.121828
# PeriodDays                              -0.029667       0.069858
# DiscoveryYear                           -0.064103      -0.009869
# RightAscension                           0.018024       0.054232
# Declination                             -0.024238       0.080142
# DistFromSunParsec                        0.012156       0.089772
# HostStarMassSlrMass                      0.147669       0.317047
# HostStarRadiusSlrRad                    -0.116323      -0.070830
# HostStarMetallicity                      1.000000       0.065470
# HostStarTempK                            0.065470       1.000000
# DiscoveryMethod_RV                       0.040008      -0.110205
# DiscoveryMethod_imaging                 -0.037042       0.202748
# DiscoveryMethod_microlensing             0.001733      -0.007241
# DiscoveryMethod_timing                   0.000332       0.077455
# DiscoveryMethod_transit                 -0.027680       0.032459
#
#                               DiscoveryMethod_RV  DiscoveryMethod_imaging  \
# TypeFlag                                0.190539                 0.087521
# RadiusJpt                              -0.157514                 0.119409
# PeriodDays                              0.019986                 0.283626
# DiscoveryYear                          -0.338186                -0.048936
# RightAscension                         -0.501126                -0.076856
# Declination                            -0.220903                -0.079912
# DistFromSunParsec                      -0.281983                -0.058276
# HostStarMassSlrMass                     0.165330                -0.037756
# HostStarRadiusSlrRad                    0.287663                -0.020783
# HostStarMetallicity                     0.040008                -0.037042
# HostStarTempK                          -0.110205                 0.202748
# DiscoveryMethod_RV                      1.000000                -0.059353
# DiscoveryMethod_imaging                -0.059353                 1.000000
# DiscoveryMethod_microlensing           -0.051968                -0.012891
# DiscoveryMethod_timing                 -0.040998                -0.010169
# DiscoveryMethod_transit                -0.905964                -0.224724
#
#                               DiscoveryMethod_microlensing  \
# TypeFlag                                          0.013100
# RadiusJpt                                        -0.035636
# PeriodDays                                       -0.000679
# DiscoveryYear                                    -0.032519
# RightAscension                                    0.020514
# Declination                                      -0.076341
# DistFromSunParsec                                 0.608630
# HostStarMassSlrMass                              -0.192322
# HostStarRadiusSlrRad                             -0.016505
# HostStarMetallicity                               0.001733
# HostStarTempK                                    -0.007241
# DiscoveryMethod_RV                               -0.051968
# DiscoveryMethod_imaging                          -0.012891
# DiscoveryMethod_microlensing                      1.000000
# DiscoveryMethod_timing                           -0.008904
# DiscoveryMethod_transit                          -0.196762
#
#                               DiscoveryMethod_timing  DiscoveryMethod_transit
# TypeFlag                                    0.091285                -0.226398
# RadiusJpt                                  -0.028113                 0.129116
# PeriodDays                                  0.023123                -0.104427
# DiscoveryYear                              -0.065231                 0.354457
# RightAscension                             -0.006505                 0.491267
# Declination                                -0.097080                 0.269936
# DistFromSunParsec                           0.009184                 0.128136
# HostStarMassSlrMass                         0.013021                -0.099564
# HostStarRadiusSlrRad                       -0.017826                -0.257959
# HostStarMetallicity                         0.000332                -0.027680
# HostStarTempK                               0.077455                 0.032459
# DiscoveryMethod_RV                         -0.040998                -0.905964
# DiscoveryMethod_imaging                    -0.010169                -0.224724
# DiscoveryMethod_microlensing               -0.008904                -0.196762
# DiscoveryMethod_timing                      1.000000                -0.155226
# DiscoveryMethod_transit                    -0.155226                 1.000000

# %% [markdown]
# Наблюдается слабая корреляция пар столбцов HostStarMassSlrMass и HostStarRadiusSlrRad, RightAscension и Declination. Чем больше радиус звезды, тем больше её масса.
#
# Посмотрим на основные характеристики

# %%
data.describe()
# Out:
#           TypeFlag    RadiusJpt     PeriodDays  DiscoveryYear  RightAscension  \
# count  3584.000000  3584.000000    3584.000000    3584.000000     3584.000000
# mean      0.097656     0.334670     522.769106    2013.308036        4.426984
# std       0.424554     0.372913    7405.684620       6.152720        1.393294
# min       0.000000     0.002300       0.090706    1781.000000        0.000000
# 25%       0.000000     0.158000       4.900976    2013.000000        4.677282
# 50%       0.000000     0.209600      13.071630    2014.000000        5.036766
# 75%       0.000000     0.266325      47.038187    2016.000000        5.133377
# max       3.000000     6.000000  320000.000000    2017.000000        6.282749
#
#        Declination  DistFromSunParsec  HostStarMassSlrMass  \
# count  3584.000000        3584.000000          3584.000000
# mean     10.197199         465.070043             0.982933
# std       3.742529         662.813464             0.311496
# min      -0.237520           1.295000             0.012000
# 25%       9.972484         226.825000             0.840000
# 50%      11.191269         333.000000             0.977000
# 75%      12.295481         456.672500             1.100000
# max      22.445677        8500.000000             4.500000
#
#        HostStarRadiusSlrRad  HostStarMetallicity  HostStarTempK  \
# count           3584.000000          3584.000000    3584.000000
# mean               1.451238             0.017359    5510.139118
# std                2.933908             0.161895    1182.636414
# min                0.000014            -2.090000     540.000000
# 25%                0.830000            -0.010000    5147.000000
# 50%                1.000000             0.020000    5634.000000
# 75%                1.220000             0.060000    5938.000000
# max               51.100000             0.560000   29300.000000
#
#        DiscoveryMethod_RV  DiscoveryMethod_imaging  \
# count         3584.000000              3584.000000
# mean             0.193080                 0.014509
# std              0.394771                 0.119593
# min              0.000000                 0.000000
# 25%              0.000000                 0.000000
# 50%              0.000000                 0.000000
# 75%              0.000000                 0.000000
# max              1.000000                 1.000000
#
#        DiscoveryMethod_microlensing  DiscoveryMethod_timing  \
# count                   3584.000000             3584.000000
# mean                       0.011161                0.006975
# std                        0.105068                0.083239
# min                        0.000000                0.000000
# 25%                        0.000000                0.000000
# 50%                        0.000000                0.000000
# 75%                        0.000000                0.000000
# max                        1.000000                1.000000
#
#        DiscoveryMethod_transit
# count              3584.000000
# mean                  0.774275
# std                   0.418118
# min                   0.000000
# 25%                   1.000000
# 50%                   1.000000
# 75%                   1.000000
# max                   1.000000

# %% [markdown]
# TypeFlag содержит целевой признак. Как видно из таблицы, более 75% элементов являются элементами класса 0.

# %% [markdown]
# ## Подготовка обучающей и тестовой выборки

# %% [markdown]
# Разобьем выборку на обучающую и тестовую

# %%
X = data.drop('TypeFlag', axis=1)
y = data['TypeFlag']


X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.5, random_state=1)

# %% [markdown]
# Перед тем как обучать модель, проведем нормализацию признаков.

# %%
scaler = MinMaxScaler()
scaler.fit_transform(X_train)
scaler.transform(X_test)
pass

# %% [markdown]
# Обучим модель KNN

# %%
model = KNeighborsClassifier()
model.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
model.score(X_train, Y_train)
# Out:
# 0.9564732142857143

# %%
model.score(X_test, Y_test)
# Out:
# 0.9369419642857143

# %% [markdown]
# На первый взгляд кажется, что модель отработала хорошо, но взглянем на матрицу ошибок

# %%
confusion_matrix(model.predict(X_test), Y_test)
# Out:
# array([[1673,   17,   80,    2],
#        [   0,    0,    0,    0],
#        [  14,    0,    6,    0],
#        [   0,    0,    0,    0]], dtype=int64)

# %% [markdown]
# Как видно из матрицы ошибок, модель определяет почти все элементы к одному классу. Это связано с дисбалансом классов и это надо как-то исправить.

# %%
Y_train.value_counts()
# Out:
# 0    1709
# 2      70
# 1      12
# 3       1
# Name: TypeFlag, dtype: int64
